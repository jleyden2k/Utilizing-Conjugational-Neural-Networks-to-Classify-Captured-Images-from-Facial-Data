# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import time
import os

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(128)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(256)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.fc1 = nn.Linear(256 * 4 * 4, 512)  # Adjusted size
        self.fc2 = nn.Linear(512, 3)
        
        self.dropout = nn.Dropout(0.2)  # Reduce if needed

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))
        x = self.pool(F.relu(self.bn4(self.conv4(x))))
        x = self.pool(F.relu(self.bn5(self.conv5(x))))
        x = x.view(x.size(0), -1)  # Flatten
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

# %%
transform_train = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(p=0.15),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.2, 0.2)),
    transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5),
    transforms.RandomGrayscale(p=0.2),
    transforms.RandomPerspective(distortion_scale=0.5, p=0.25),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.2, scale=(0.02, 0.2)),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


# Validation transformations (NO augmentations)
transform_val = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize to match training
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load dataset (replace 'train_data_path' and 'val_data_path' with actual paths)
train_dataset = datasets.ImageFolder(root='MLDL_Data_Face-1/train', transform=transform_train)
val_dataset = datasets.ImageFolder(root='MLDL_Data_Face-1/val', transform=transform_val)

from sklearn.model_selection import StratifiedKFold
from torch.utils.data import Subset
import numpy as np

# Define number of folds
num_folds = 5

# Extract image paths and labels from train_dataset
image_paths = np.array(train_dataset.imgs)  # Full dataset image paths
labels = np.array(train_dataset.targets)  # Corresponding labels

# Set up Stratified K-Fold
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedKFold

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.backends.cudnn.benchmark = True  # Speed up training if inputs are same size

# Compute class weights once before training (not in every fold)
class_counts = [4541, 5453, 4945]
class_weights = torch.FloatTensor([sum(class_counts) / count for count in class_counts]).to(device)

scaler = torch.amp.GradScaler('cuda')  # Use mixed precision for speedup

train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []

# Perform cross-validation
for fold, (train_idx, val_idx) in enumerate(skf.split(image_paths, labels)):
    print(f"Training on fold {fold + 1}/{num_folds}...")

    train_subset = Subset(train_dataset, train_idx)
    val_subset = Subset(train_dataset, val_idx)

    train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

    model = SimpleCNN().to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

    patience = 6
    best_val_loss = float('inf')
    counter = 0

    num_epochs = 50
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            
            with torch.amp.autocast('cuda'):  # Enable Mixed Precision
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct / total

        # Validation
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)

                with torch.amp.autocast('cuda'):
                    outputs = model(images)
                    loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_loss /= len(val_loader)
        val_acc = 100 * correct / total

        print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_acc)
        val_accuracies.append(val_acc)

        # Early Stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print("Early stopping triggered.")
                break

        scheduler.step()
# Out:
# Training on fold 1/5...
# Epoch [1/50], Train Loss: 1.0760, Train Acc: 41.07%, Val Loss: 1.0327, Val Acc: 43.41%
# Epoch [2/50], Train Loss: 0.9693, Train Acc: 50.74%, Val Loss: 1.0587, Val Acc: 46.79%
# Epoch [3/50], Train Loss: 0.8547, Train Acc: 58.84%, Val Loss: 0.7906, Val Acc: 64.36%
# Epoch [4/50], Train Loss: 0.7534, Train Acc: 65.16%, Val Loss: 0.7342, Val Acc: 64.83%
# Epoch [5/50], Train Loss: 0.6815, Train Acc: 69.57%, Val Loss: 0.7444, Val Acc: 65.19%
# Epoch [21/50], Train Loss: 0.3460, Train Acc: 85.95%, Val Loss: 0.3258, Val Acc: 86.65%
# Epoch [22/50], Train Loss: 0.3405, Train Acc: 86.60%, Val Loss: 0.3045, Val Acc: 87.85%
# Epoch [23/50], Train Loss: 0.3354, Train Acc: 86.92%, Val Loss: 0.3226, Val Acc: 87.22%
# Epoch [24/50], Train Loss: 0.3282, Train Acc: 86.92%, Val Loss: 0.2928, Val Acc: 88.42%
# Epoch [25/50], Train Loss: 0.3326, Train Acc: 86.58%, Val Loss: 0.3076, Val Acc: 87.42%
# Epoch [26/50], Train Loss: 0.3229, Train Acc: 87.41%, Val Loss: 0.3158, Val Acc: 87.68%
# Epoch [27/50], Train Loss: 0.3325, Train Acc: 86.92%, Val Loss: 0.2980, Val Acc: 88.52%
# Epoch [28/50], Train Loss: 0.3274, Train Acc: 87.21%, Val Loss: 0.3011, Val Acc: 88.32%
# Epoch [29/50], Train Loss: 0.3191, Train Acc: 87.70%, Val Loss: 0.2866, Val Acc: 88.76%
# Epoch [30/50], Train Loss: 0.3275, Train Acc: 86.96%, Val Loss: 0.2928, Val Acc: 88.99%
# Epoch [31/50], Train Loss: 0.3174, Train Acc: 87.28%, Val Loss: 0.2899, Val Acc: 88.55%
# Epoch [32/50], Train Loss: 0.3240, Train Acc: 87.22%, Val Loss: 0.2888, Val Acc: 88.79%
# Epoch [33/50], Train Loss: 0.3235, Train Acc: 87.61%, Val Loss: 0.3000, Val Acc: 87.95%
# Epoch [34/50], Train Loss: 0.3141, Train Acc: 87.78%, Val Loss: 0.2764, Val Acc: 89.26%
# Epoch [35/50], Train Loss: 0.3214, Train Acc: 87.62%, Val Loss: 0.2937, Val Acc: 88.79%
# Epoch [36/50], Train Loss: 0.3155, Train Acc: 87.59%, Val Loss: 0.2815, Val Acc: 89.26%
# Epoch [37/50], Train Loss: 0.3168, Train Acc: 87.52%, Val Loss: 0.3025, Val Acc: 87.72%
# Epoch [38/50], Train Loss: 0.3227, Train Acc: 87.31%, Val Loss: 0.2921, Val Acc: 88.52%
# Epoch [39/50], Train Loss: 0.3132, Train Acc: 87.91%, Val Loss: 0.3013, Val Acc: 87.85%
# Epoch [40/50], Train Loss: 0.3152, Train Acc: 87.39%, Val Loss: 0.2910, Val Acc: 88.92%
# Early stopping triggered.
# Training on fold 4/5...
# Epoch [1/50], Train Loss: 1.0670, Train Acc: 42.21%, Val Loss: 1.0063, Val Acc: 48.03%
# Epoch [2/50], Train Loss: 0.9602, Train Acc: 51.64%, Val Loss: 0.8675, Val Acc: 56.09%
# Epoch [3/50], Train Loss: 0.8678, Train Acc: 56.84%, Val Loss: 0.8713, Val Acc: 57.90%
# Epoch [4/50], Train Loss: 0.7716, Train Acc: 63.71%, Val Loss: 0.7895, Val Acc: 61.45%
# Epoch [5/50], Train Loss: 0.7007, Train Acc: 67.64%, Val Loss: 0.6513, Val Acc: 71.69%
# Epoch [6/50], Train Loss: 0.6059, Train Acc: 73.08%, Val Loss: 0.5815, Val Acc: 73.76%
# Epoch [7/50], Train Loss: 0.5454, Train Acc: 76.44%, Val Loss: 0.5292, Val Acc: 77.74%
# Epoch [8/50], Train Loss: 0.5260, Train Acc: 77.44%, Val Loss: 0.4816, Val Acc: 78.95%
# Epoch [9/50], Train Loss: 0.4914, Train Acc: 78.93%, Val Loss: 0.4759, Val Acc: 79.92%
# Epoch [10/50], Train Loss: 0.4642, Train Acc: 80.70%, Val Loss: 0.4686, Val Acc: 79.89%
# Epoch [11/50], Train Loss: 0.4240, Train Acc: 82.76%, Val Loss: 0.3901, Val Acc: 84.04%
# Epoch [12/50], Train Loss: 0.4072, Train Acc: 83.54%, Val Loss: 0.4062, Val Acc: 83.67%
# Epoch [13/50], Train Loss: 0.4086, Train Acc: 83.01%, Val Loss: 0.3737, Val Acc: 84.91%
# Epoch [14/50], Train Loss: 0.3886, Train Acc: 83.93%, Val Loss: 0.3603, Val Acc: 85.68%
# Epoch [15/50], Train Loss: 0.3900, Train Acc: 83.89%, Val Loss: 0.3458, Val Acc: 86.08%
# Epoch [16/50], Train Loss: 0.3604, Train Acc: 85.59%, Val Loss: 0.3406, Val Acc: 86.04%
# Epoch [17/50], Train Loss: 0.3552, Train Acc: 85.90%, Val Loss: 0.3422, Val Acc: 86.21%
# Epoch [18/50], Train Loss: 0.3501, Train Acc: 86.30%, Val Loss: 0.3268, Val Acc: 86.65%
# Epoch [19/50], Train Loss: 0.3454, Train Acc: 86.15%, Val Loss: 0.3263, Val Acc: 86.68%
# Epoch [20/50], Train Loss: 0.3318, Train Acc: 86.67%, Val Loss: 0.3167, Val Acc: 87.32%
# Epoch [21/50], Train Loss: 0.3325, Train Acc: 87.05%, Val Loss: 0.3168, Val Acc: 87.52%
# Epoch [22/50], Train Loss: 0.3250, Train Acc: 87.13%, Val Loss: 0.3068, Val Acc: 87.78%
# Epoch [23/50], Train Loss: 0.3362, Train Acc: 86.71%, Val Loss: 0.3017, Val Acc: 87.95%
# Epoch [24/50], Train Loss: 0.3303, Train Acc: 86.90%, Val Loss: 0.3030, Val Acc: 87.78%
# Epoch [25/50], Train Loss: 0.3273, Train Acc: 86.71%, Val Loss: 0.3056, Val Acc: 87.75%
# Epoch [26/50], Train Loss: 0.3112, Train Acc: 87.89%, Val Loss: 0.3020, Val Acc: 87.92%
# Epoch [27/50], Train Loss: 0.3225, Train Acc: 87.46%, Val Loss: 0.2977, Val Acc: 87.92%
# Epoch [28/50], Train Loss: 0.3151, Train Acc: 87.38%, Val Loss: 0.3031, Val Acc: 88.15%
# Epoch [29/50], Train Loss: 0.3168, Train Acc: 87.42%, Val Loss: 0.2825, Val Acc: 88.49%
# Epoch [30/50], Train Loss: 0.3188, Train Acc: 87.62%, Val Loss: 0.3017, Val Acc: 88.72%
# Epoch [31/50], Train Loss: 0.3137, Train Acc: 87.73%, Val Loss: 0.2881, Val Acc: 88.59%
# Epoch [32/50], Train Loss: 0.3211, Train Acc: 87.15%, Val Loss: 0.3085, Val Acc: 87.75%
# Epoch [33/50], Train Loss: 0.3073, Train Acc: 88.12%, Val Loss: 0.3002, Val Acc: 88.15%
# Epoch [34/50], Train Loss: 0.3124, Train Acc: 87.71%, Val Loss: 0.2814, Val Acc: 89.22%
# Epoch [35/50], Train Loss: 0.3108, Train Acc: 87.69%, Val Loss: 0.2934, Val Acc: 88.02%
# Epoch [36/50], Train Loss: 0.3110, Train Acc: 87.63%, Val Loss: 0.2920, Val Acc: 88.49%
# Epoch [37/50], Train Loss: 0.3029, Train Acc: 88.26%, Val Loss: 0.3005, Val Acc: 88.02%
# Epoch [38/50], Train Loss: 0.3080, Train Acc: 88.02%, Val Loss: 0.2869, Val Acc: 88.52%
# Epoch [39/50], Train Loss: 0.3101, Train Acc: 87.57%, Val Loss: 0.2869, Val Acc: 89.12%
# Epoch [40/50], Train Loss: 0.3083, Train Acc: 87.63%, Val Loss: 0.2927, Val Acc: 89.36%
# Early stopping triggered.
# Training on fold 5/5...
# Epoch [1/50], Train Loss: 1.0669, Train Acc: 41.95%, Val Loss: 1.0265, Val Acc: 45.23%
# Epoch [2/50], Train Loss: 0.9622, Train Acc: 50.93%, Val Loss: 0.9474, Val Acc: 51.46%
# Epoch [3/50], Train Loss: 0.8629, Train Acc: 58.02%, Val Loss: 0.7971, Val Acc: 61.50%
# Epoch [4/50], Train Loss: 0.7542, Train Acc: 64.99%, Val Loss: 0.7403, Val Acc: 65.45%
# Epoch [5/50], Train Loss: 0.6883, Train Acc: 68.54%, Val Loss: 0.6516, Val Acc: 70.27%
# Epoch [6/50], Train Loss: 0.5830, Train Acc: 74.48%, Val Loss: 0.5288, Val Acc: 77.50%
# Epoch [7/50], Train Loss: 0.5536, Train Acc: 75.82%, Val Loss: 0.5095, Val Acc: 78.51%
# Epoch [8/50], Train Loss: 0.5218, Train Acc: 77.89%, Val Loss: 0.5272, Val Acc: 76.00%
# Epoch [9/50], Train Loss: 0.4901, Train Acc: 79.36%, Val Loss: 0.4782, Val Acc: 79.54%
# Epoch [10/50], Train Loss: 0.4713, Train Acc: 80.28%, Val Loss: 0.4391, Val Acc: 82.42%
# Epoch [11/50], Train Loss: 0.4345, Train Acc: 81.92%, Val Loss: 0.4015, Val Acc: 83.56%
# Epoch [12/50], Train Loss: 0.4150, Train Acc: 83.19%, Val Loss: 0.3779, Val Acc: 84.67%
# Epoch [13/50], Train Loss: 0.4063, Train Acc: 83.49%, Val Loss: 0.3735, Val Acc: 85.30%
# Epoch [14/50], Train Loss: 0.3998, Train Acc: 83.22%, Val Loss: 0.3895, Val Acc: 84.03%
# Epoch [15/50], Train Loss: 0.3835, Train Acc: 84.45%, Val Loss: 0.3496, Val Acc: 85.04%
# Epoch [16/50], Train Loss: 0.3673, Train Acc: 85.44%, Val Loss: 0.3402, Val Acc: 86.98%
# Epoch [17/50], Train Loss: 0.3620, Train Acc: 85.44%, Val Loss: 0.3284, Val Acc: 87.04%
# Epoch [18/50], Train Loss: 0.3680, Train Acc: 85.19%, Val Loss: 0.3190, Val Acc: 87.78%
# Epoch [19/50], Train Loss: 0.3475, Train Acc: 86.04%, Val Loss: 0.3123, Val Acc: 87.41%
# Epoch [20/50], Train Loss: 0.3465, Train Acc: 85.97%, Val Loss: 0.3060, Val Acc: 87.78%
# Epoch [21/50], Train Loss: 0.3491, Train Acc: 86.11%, Val Loss: 0.3064, Val Acc: 87.98%
# Epoch [22/50], Train Loss: 0.3420, Train Acc: 86.43%, Val Loss: 0.3019, Val Acc: 87.55%
# Epoch [23/50], Train Loss: 0.3389, Train Acc: 86.55%, Val Loss: 0.3090, Val Acc: 87.78%
# Epoch [24/50], Train Loss: 0.3404, Train Acc: 86.30%, Val Loss: 0.3008, Val Acc: 87.98%
# Epoch [25/50], Train Loss: 0.3249, Train Acc: 87.03%, Val Loss: 0.3087, Val Acc: 87.95%
# Epoch [26/50], Train Loss: 0.3264, Train Acc: 86.96%, Val Loss: 0.3043, Val Acc: 88.15%
# Epoch [27/50], Train Loss: 0.3277, Train Acc: 86.80%, Val Loss: 0.2994, Val Acc: 88.68%
# Epoch [28/50], Train Loss: 0.3257, Train Acc: 87.34%, Val Loss: 0.3144, Val Acc: 87.71%
# Epoch [29/50], Train Loss: 0.3219, Train Acc: 87.30%, Val Loss: 0.2964, Val Acc: 88.32%
# Epoch [30/50], Train Loss: 0.3210, Train Acc: 87.30%, Val Loss: 0.2971, Val Acc: 88.55%
# Epoch [31/50], Train Loss: 0.3251, Train Acc: 86.90%, Val Loss: 0.2921, Val Acc: 88.35%
# Epoch [32/50], Train Loss: 0.3276, Train Acc: 86.82%, Val Loss: 0.3059, Val Acc: 87.41%
# Epoch [33/50], Train Loss: 0.3169, Train Acc: 87.48%, Val Loss: 0.2850, Val Acc: 89.02%
# Epoch [34/50], Train Loss: 0.3185, Train Acc: 87.32%, Val Loss: 0.2698, Val Acc: 89.76%
# Epoch [35/50], Train Loss: 0.3232, Train Acc: 86.91%, Val Loss: 0.2933, Val Acc: 88.75%
# Epoch [36/50], Train Loss: 0.3192, Train Acc: 87.78%, Val Loss: 0.2877, Val Acc: 89.15%
# Epoch [37/50], Train Loss: 0.3106, Train Acc: 87.68%, Val Loss: 0.2831, Val Acc: 89.39%
# Epoch [38/50], Train Loss: 0.3155, Train Acc: 87.60%, Val Loss: 0.3006, Val Acc: 88.35%
# Epoch [39/50], Train Loss: 0.3194, Train Acc: 87.41%, Val Loss: 0.2993, Val Acc: 88.25%
# Epoch [40/50], Train Loss: 0.3236, Train Acc: 87.16%, Val Loss: 0.2966, Val Acc: 88.58%
# Early stopping triggered.

# %%
timestamp = time.strftime('%Y%m%d_%H%M%S')
checkpoint_filename = f'checkpoint_epoch_{epoch}_{timestamp}.pth'
torch.save({
    'epoch': epoch,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': val_loss,
}, checkpoint_filename)

# %%
""" checkpoint_path = 'checkpoint_epoch_1_20250320_171718.pth'
checkpoint = torch.load(checkpoint_path)
model.load_state_dict(checkpoint['model_state_dict'])
 """
# Out:
# " checkpoint_path = 'checkpoint_epoch_1_20250320_171718.pth'\ncheckpoint = torch.load(checkpoint_path)\nmodel.load_state_dict(checkpoint['model_state_dict'])\n "

# %%
import matplotlib.pyplot as plt

# Example: Training and Validation loss over epochs
epochs = range(1, len(train_losses) + 1)

# Plot loss
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy', color='blue')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
